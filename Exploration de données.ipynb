# %%
# !ls ai4r
# Out:
# ls: cannot access 'ai4r': No such file or directory

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('Solarize_Light2')

# %%
Data = pd.read_csv('/work/Car_Insurance_Claim_G.csv',sep=';')
Data.head()
# Out:
#        ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0  569520    65+  female  majority               0-9y  high school
# 1  750365  16-25    male  majority               0-9y         none
# 2  199901  16-25  female  majority               0-9y  high school
# 3  478866  16-25    male  majority               0-9y   university
# 4  731664  26-39    male  majority             10-19y         none
#
#           INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# 0    upper class      0.629027                1.0   after 2015      0.0
# 1        poverty      0.357757                0.0  before 2015      0.0
# 2  working class      0.493146                1.0  before 2015      0.0
# 3  working class      0.206013                1.0  before 2015      0.0
# 4  working class      0.388366                1.0  before 2015      0.0
#
#    CHILDREN  POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# ...

# %%
Data.shape
# Out:
# (10000, 19)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         9018 non-null   float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       9043 non-null   float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %%
Data.median()
# Out:
# ID                     501777.000000
# CREDIT_SCORE                0.525033
# VEHICLE_OWNERSHIP           1.000000
# MARRIED                     0.000000
# CHILDREN                    1.000000
# POSTAL_CODE             10238.000000
# ANNUAL_MILEAGE          12000.000000
# SPEEDING_VIOLATIONS         0.000000
# DUIS                        0.000000
# PAST_ACCIDENTS              0.000000
# OUTCOME                     0.000000
# dtype: float64

# %%
Data.describe()
# Out:
#                   ID  CREDIT_SCORE  VEHICLE_OWNERSHIP       MARRIED  \
# count   10000.000000   9018.000000       10000.000000  10000.000000
# mean   500521.906800      0.515813           0.697000      0.498200
# std    290030.768758      0.137688           0.459578      0.500022
# min       101.000000      0.053358           0.000000      0.000000
# 25%    249638.500000      0.417191           0.000000      0.000000
# 50%    501777.000000      0.525033           1.000000      0.000000
# 75%    753974.500000      0.618312           1.000000      1.000000
# max    999976.000000      0.960819           1.000000      1.000000
#
#            CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# count  10000.000000  10000.000000     9043.000000         10000.000000
# mean       0.688800  19864.548400    11697.003207             1.482900
# std        0.463008  18915.613855     2818.434528             2.241966
# ...

# %%
Data['CREDIT_SCORE'].mean()
# Out:
# 0.515812809602791

# %%
Genre = Data['GENDER'].value_counts()

# %%
plt.pie(Genre,labels=Genre.index,shadow=True)
plt.legend('Genres')
plt.show()

# %%
Data['RACE'].value_counts(normalize=True)
# Out:
# majority    0.9012
# minority    0.0988
# Name: RACE, dtype: float64

# %%
Data.head()
# Out:
#        ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0  569520    65+  female  majority               0-9y  high school
# 1  750365  16-25    male  majority               0-9y         none
# 2  199901  16-25  female  majority               0-9y  high school
# 3  478866  16-25    male  majority               0-9y   university
# 4  731664  26-39    male  majority             10-19y         none
#
#           INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# 0    upper class      0.629027                1.0   after 2015      0.0
# 1        poverty      0.357757                0.0  before 2015      0.0
# 2  working class      0.493146                1.0  before 2015      0.0
# 3  working class      0.206013                1.0  before 2015      0.0
# 4  working class      0.388366                1.0  before 2015      0.0
#
#    CHILDREN  POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# ...

# %%
Data['VEHICLE_YEAR'].value_counts(normalize=True)
# Out:
# before 2015    0.6967
# after 2015     0.3033
# Name: VEHICLE_YEAR, dtype: float64

# %%
Income = Data.groupby(['INCOME'])

# %%
Data['INCOME'].value_counts()
# Out:
# upper class      4336
# middle class     2138
# poverty          1814
# working class    1712
# Name: INCOME, dtype: int64

# %%
Upper_class = Income.get_group('upper class')
Upper_class
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0     569520    65+  female  majority               0-9y  high school
# 5     877557  40-64  female  majority             20-29y  high school
# 6     930134    65+    male  majority               30y+  high school
# 9     445911  40-64  female  majority               0-9y  high school
# 10    275820    65+    male  majority               30y+  high school
# ...      ...    ...     ...       ...                ...          ...
# 9978   38769  40-64  female  majority             20-29y  high school
# 9991   67445  26-39    male  majority             10-19y   university
# 9992  188300    65+    male  majority             10-19y   university
# 9993  156495  26-39    male  majority             10-19y   university
# 9995  323164  26-39  female  majority             10-19y   university
#
#            INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
Middle_class = Income.get_group('middle class')
Middle_class
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 14    980181  26-39    male  majority             10-19y  high school
# 21    912828  16-25    male  majority               0-9y  high school
# 25    193110  26-39  female  majority             10-19y   university
# 26     98515  40-64    male  majority             10-19y  high school
# 28    493590  26-39    male  majority             10-19y   university
# ...      ...    ...     ...       ...                ...          ...
# 9986  376624  40-64    male  majority             20-29y  high school
# 9989  801998  40-64    male  majority             20-29y  high school
# 9994  752887  26-39    male  majority             10-19y  high school
# 9996  910346  26-39  female  majority             10-19y         none
# 9997  468409  26-39    male  majority               0-9y  high school
#
#             INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
Poverty =Income.get_group('poverty')
Poverty
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 1     750365  16-25    male  majority               0-9y         none
# 17     24851  16-25    male  majority               0-9y         none
# 22    892754  40-64    male  majority             20-29y         none
# 23       217  16-25    male  majority               0-9y         none
# 27    165623  26-39    male  majority             10-19y         none
# ...      ...    ...     ...       ...                ...          ...
# 9975  305486  16-25    male  majority               0-9y  high school
# 9976  725307  26-39    male  majority             10-19y         none
# 9980  135257  40-64  female  majority             20-29y  high school
# 9988  479789  26-39    male  majority             10-19y  high school
# 9998  903459  26-39  female  majority             10-19y  high school
#
#        INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
Working_class = Income.get_group('working class')
Working_class
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 2     199901  16-25  female  majority               0-9y  high school
# 3     478866  16-25    male  majority               0-9y   university
# 4     731664  26-39    male  majority             10-19y         none
# 7     461006  26-39  female  majority               0-9y   university
# 8      68366  40-64  female  majority             20-29y   university
# ...      ...    ...     ...       ...                ...          ...
# 9983  124282  40-64  female  majority             20-29y  high school
# 9985  595418  16-25    male  minority               0-9y  high school
# 9987  735333  40-64    male  majority             20-29y  high school
# 9990  302403  16-25  female  majority               0-9y  high school
# 9999  442696  26-39  female  majority               0-9y         none
#
#              INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
pd.crosstab(Data['GENDER'],Data['INCOME'])
# Out:
# INCOME  middle class  poverty  upper class  working class
# GENDER
# female          1078      957         2117            858
# male            1060      857         2219            854

# %%
pd.crosstab(Data['GENDER'],['Working_class'])
# Out:
# col_0   Working_class
# GENDER
# female           5010
# male             4990

# %%
pd.crosstab(Data['GENDER'],['Middle_class'])
# Out:
# col_0   Middle_class
# GENDER
# female          5010
# male            4990

# %%
Education = Data['EDUCATION'].value_counts()

# %%
plt.pie(Education, labels = Education.index,shadow=True)
plt.legend('Education title')
plt.show()

# %%
pd.crosstab(Data['GENDER'],['Poverty'])
# Out:
# col_0   Poverty
# GENDER
# female     5010
# male       4990

# %%
pd.crosstab(Data['GENDER'],['Upper_class'])
# Out:
# col_0   Upper_class
# GENDER
# female         5010
# male           4990

# %%
Education = Data.groupby(['EDUCATION'])

# %%
Education.get_group('university')
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE   EDUCATION  \
# 3     478866  16-25    male  majority               0-9y  university
# 7     461006  26-39  female  majority               0-9y  university
# 8      68366  40-64  female  majority             20-29y  university
# 13    569640  16-25  female  majority               0-9y  university
# 16    517747    65+    male  majority               30y+  university
# ...      ...    ...     ...       ...                ...         ...
# 9979  503171  40-64    male  majority             20-29y  university
# 9991   67445  26-39    male  majority             10-19y  university
# 9992  188300    65+    male  majority             10-19y  university
# 9993  156495  26-39    male  majority             10-19y  university
# 9995  323164  26-39  female  majority             10-19y  university
#
#              INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
Education.get_group('high school')
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0     569520    65+  female  majority               0-9y  high school
# 2     199901  16-25  female  majority               0-9y  high school
# 5     877557  40-64  female  majority             20-29y  high school
# 6     930134    65+    male  majority               30y+  high school
# 9     445911  40-64  female  majority               0-9y  high school
# ...      ...    ...     ...       ...                ...          ...
# 9989  801998  40-64    male  majority             20-29y  high school
# 9990  302403  16-25  female  majority               0-9y  high school
# 9994  752887  26-39    male  majority             10-19y  high school
# 9997  468409  26-39    male  majority               0-9y  high school
# 9998  903459  26-39  female  majority             10-19y  high school
#
#              INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
pd.crosstab(Data['GENDER'],Data['AGE'])
# Out:
# AGE     16-25  26-39  40-64  65+
# GENDER
# female   1034   1515   1466  995
# male      982   1548   1465  995

# %%
Filt = Data['RACE'] == 'majority'
Data.loc[Filt]
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0     569520    65+  female  majority               0-9y  high school
# 1     750365  16-25    male  majority               0-9y         none
# 2     199901  16-25  female  majority               0-9y  high school
# 3     478866  16-25    male  majority               0-9y   university
# 4     731664  26-39    male  majority             10-19y         none
# ...      ...    ...     ...       ...                ...          ...
# 9995  323164  26-39  female  majority             10-19y   university
# 9996  910346  26-39  female  majority             10-19y         none
# 9997  468409  26-39    male  majority               0-9y  high school
# 9998  903459  26-39  female  majority             10-19y  high school
# 9999  442696  26-39  female  majority               0-9y         none
#
#              INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
Income['EDUCATION'].value_counts()
# Out:
# INCOME         EDUCATION
# middle class   high school    1112
#                university      740
#                none            286
# poverty        none            983
#                high school     734
#                university       97
# upper class    university     2766
#                high school    1428
#                none            142
# working class  high school     883
#                none            504
#                university      325
# Name: EDUCATION, dtype: int64

# %%
Income['AGE'].value_counts()
# Out:
# INCOME         AGE
# middle class   26-39     924
#                40-64     717
#                16-25     315
#                65+       182
# poverty        16-25    1097
#                26-39     600
#                40-64     112
#                65+         5
# upper class    65+      1758
#                40-64    1751
#                26-39     748
#                16-25      79
# working class  26-39     791
#                16-25     525
#                40-64     351
#                65+        45
# Name: AGE, dtype: int64

# %%
Income['VEHICLE_YEAR'].value_counts()
# Out:
# INCOME         VEHICLE_YEAR
# middle class   before 2015     1570
#                after 2015       568
# poverty        before 2015     1695
#                after 2015       119
# upper class    before 2015     2248
#                after 2015      2088
# working class  before 2015     1454
#                after 2015       258
# Name: VEHICLE_YEAR, dtype: int64

# %% [markdown]
# ##

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7fa9bb0d-2f1a-4417-8561-8b4bf393f1c8' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
